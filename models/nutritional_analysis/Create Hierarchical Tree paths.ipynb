# %%
#pip install networkx[default]

# %%
import json
import networkx as nx
import numpy as np
import pandas as pd

from sklearn.cluster import AgglomerativeClustering

# %%
# csv paths
nutrient_matrix_data_p = r"../../data/Nutrients_Branded_Foods_2018/"

nutrient_matrix_csv_p = nutrient_matrix_data_p + "nutrients_matrix.csv.gz"

# %%
#parameters to save the linkage matrix
metric = 'euclidean'

linkage = 'single'

fname = nutrient_matrix_data_p + 'hcluster_nutrients_' + metric + '_' + linkage + '.npy'

# %%
#read data
nutrients_matrix = pd.read_csv(nutrient_matrix_csv_p)
#set ndb no as index
nutrients_matrix.set_index("NDB_No", inplace = True)
#create a list of indices where all entries are zero
nutrients_zero_rows = nutrients_matrix.loc[(nutrients_matrix==0).all(axis=1)].index
#filter out indicies where all entires are zero
nutrients_matrix = nutrients_matrix[~nutrients_matrix.index.isin(nutrients_zero_rows)]
print(nutrients_matrix.shape)
# Out:
# (234247, 94)

# %%
sample = nutrients_matrix.sample(frac = 0.1, random_state = 1)

# %%
clusters, _ = sample.shape
clusters = round(clusters*0.02)

# %%
agglo_cluster = AgglomerativeClustering(n_clusters = clusters, metric=metric, linkage = linkage, compute_full_tree = False).fit(sample)

# %%
agglo_cluster.labels_
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
linkage_matrix = agglo_cluster.children_

# %%
linkage_matrix.shape
# Out:
# (23424, 2)

# %% [markdown]
# #### Create a json object from the linkage matrix

# %%
linkage_matrix = np.load(fname, allow_pickle=True)

# %%
linkage_matrix
# Out:
# array([[ 98077, 189065],
#        [ 49193, 157413],
#        [ 47853,  93762],
#        ...,
#        [468489,  77617],
#        [468490, 218766],
#        [468491, 201900]])

# %%
from heapq import heapify, heappop, heappush, heappushpop

# %%
n_clusters = round(nutrients_matrix.shape[0]*0.02)
children = linkage_matrix
n_leaves = nutrients_matrix.shape[0]

# %%
n_clusters
# Out:
# 4685

# %%
nodes = [-(max(linkage_matrix[-1]) + 1)]

# %%
nodes
# Out:
# [-468487, -201900, -218766, -77617, -176764, -93184]

# %%
these_children = children[-nodes[0] - n_leaves]

# %%
-these_children
# Out:
# array([-468489,  -77617])

# %%
heappush(nodes, -these_children[0])
nodes
# Out:
# [-468490, -468489, -218766, -201900]

# %%
heappushpop(nodes, -these_children[1])
nodes
# Out:
# [-468489, -201900, -218766, -77617]

# %%
for _ in range(n_clusters - 1):
    # As we have a heap, nodes[0] is the smallest element
    these_children = children[-nodes[0] - n_leaves]
    # Insert the 2 children and remove the largest node
    heappush(nodes, -these_children[0])
    heappushpop(nodes, -these_children[1])

# %%
nodes[0:5]
# Out:
# [-463808, -463807, -463802, -463804, -463799]

# %%
len(nodes)
# Out:
# 4685

# %%
label = np.zeros(n_leaves, dtype=np.intp)

# %%
label[[0,1,2,3]]=1

# %%
label[0:5]
# Out:
# array([1, 1, 1, 1, 0], dtype=int64)

# %%
node = -nodes[0]

# %%
node
# Out:
# 463808

# %%
ind = [node]
descendent = []

# It is actually faster to do the accounting of the number of
# elements is the list ourselves: len is a lengthy operation on a
# chained list
#cdef cnp.intp_t i, 
n_indices = 1

while n_indices:
    i = ind.pop()
    if i < n_leaves:
        descendent.append(i)
        n_indices -= 1
    else:
        ind.extend(children[i - n_leaves])
        n_indices += 1
descendent
# Out:
# [13206, 13205, 214823, 1103]

# %%
DG = nx.DiGraph()

# %%
num_rows, _ = linkage_matrix.shape
i = 0
# loop linked matrix convert to dictionary
for row in linkage_matrix:
    i += 1
    DG.add_edge(row[0], i + num_rows)
    DG.add_edge(row[1], i + num_rows)

# %%
g = list(DG.nodes)

# %%
print(nx.shortest_path(DG, source=20000, target = max(g)))
# Out:
# [20000, 37327, 37334, 37336, 37350, 37355, 37361, 37365, 37367, 37370, 37384, 37386, 37399, 37404, 37405, 37406, 37412, 37414, 37422, 37423, 37429, 37432, 37437, 37445, 37446, 37447, 37449, 37454, 37460, 37462, 37465, 37466, 37469, 37470, 37472, 37477, 37484, 37489, 37490, 37497, 37499, 37509, 37515, 37516, 37520, 37522, 37523, 37524, 37526, 37527, 37528, 37533, 37540, 37543, 37545, 37547, 37548, 37550, 37551, 37554, 37557, 37559, 37562, 37563, 37564, 37566, 37570, 37571, 37575, 37589, 37590, 37593, 37597, 37599, 37602, 37605, 37606, 37609, 37615, 37617, 37620, 37622, 37623, 37627, 37631, 37637, 37638, 37643, 37646, 37650, 37654, 37655, 37662, 37663, 37664, 37666, 37668, 37670, 37675, 37678, 37679, 37682, 37685, 37688, 37689, 37697, 37698, 37700, 37701, 37705, 37706, 37708, 37710, 37722, 37723, 37724, 37731, 37733, 37735, 37736, 37737, 37739, 37743, 37753, 37758, 37760, 37762, 37763, 37767, 37768, 37771, 37774, 37780, 37781, 37782, 37784, 37790, 37800, 37802, 37805, 37806, 37809, 37813, 37814, 37815, 37816, 37818, 37821, 37831, 37832, 37834, 37836, 37838, 37839, 37840, 37844, 37847, 37848, 37852, 37859, 37865, 37872, 37878, 37880, 37881, 37883, 37885, 37893, 37896, 37898, 37905, 37907, 37909, 37910, 37912, 37915, 37918, 37924, 37926, 37927, 37931, 37932, 37938, 37940, 37942, 37945, 37948, 37949, 37955, 37962, 37967, 37968, 37969, 37975, 37976, 37977, 37984, 37987, 37993, 37994, 37995, 37997, 38000, 38001, 38004, 38008, 38009, 38010, 38012, 38015, 38018, 38019, 38027, 38028, 38030, 38036, 38038, 38040, 38047, 38053, 38055, 38056, 38057, 38058, 38060, 38063, 38065, 38071, 38078, 38079, 38081, 38083, 38085, 38087, 38089, 38092, 38094, 38095, 38096, 38098, 38102, 38106, 38108, 38112, 38116, 38117, 38121, 38124, 38129, 38133, 38134, 38137, 38138, 38139, 38142, 38144, 38146, 38150, 38152, 38153, 38161, 38163, 38164, 38166, 38169, 38170, 38175, 38178, 38181, 38187, 38188, 38189, 38190, 38191, 38194, 38197, 38201, 38203, 38206, 38210, 38211, 38218, 38220, 38221, 38223, 38224, 38231, 38233, 38234, 38236, 38238, 38240, 38242, 38247, 38254, 38259, 38261, 38264, 38269, 38271, 38276, 38277, 38284, 38287, 38289, 38291, 38296, 38299, 38301, 38304, 38305, 38307, 38312, 38319, 38320, 38322, 38324, 38326, 38328, 38329, 38330, 38340, 38347, 38348, 38352, 38355, 38356, 38357, 38358, 38360, 38361, 38362, 38365, 38368, 38369, 38372, 38373, 38378, 38379, 38380, 38383, 38384, 38394, 38396, 38397, 38400, 38406, 38407, 38415, 38418, 38419, 38421, 38423, 38427, 38429, 38430, 38432, 38434, 38439, 38440, 38443, 38444, 38448, 38451, 38452, 38456, 38457, 38458, 38463, 38468, 38469, 38472, 38474, 38476, 38477, 38480, 38482, 38484, 38485, 38489, 38490, 38491, 38493, 38498, 38500, 38503, 38506, 38513, 38514, 38515, 38518, 38519, 38522, 38531, 38534, 38535, 38537, 38538, 38539, 38540, 38542, 38544, 38546, 38550, 38551, 38552, 38553, 38554, 38555, 38557, 38560, 38561, 38565, 38567, 38569, 38575, 38577, 38578, 38582, 38583, 38587, 38593, 38595, 38596, 38601, 38602, 38603, 38606, 38610, 38615, 38617, 38618, 38622, 38624, 38625, 38631, 38633, 38634, 38635, 38637, 38639, 38640, 38641, 38643, 38644, 38646, 38647, 38649, 38650, 38655, 38664, 38667, 38670, 38672, 38675, 38677, 38678, 38680, 38682, 38684, 38686, 38687, 38690, 38692, 38693, 38695, 38696, 38697, 38698, 38699, 38701, 38702, 38706, 38707, 38710, 38713, 38715, 38721, 38722, 38723, 38726, 38727, 38733, 38736, 38737, 38739, 38744, 38745, 38746, 38747, 38752, 38753, 38754, 38756, 38759, 38761, 38765, 38766, 38769, 38770, 38772, 38773, 38774, 38775, 38776, 38779, 38780, 38784, 38785, 38786, 38787, 38790, 38792, 38796, 38803, 38804, 38806, 38807, 38811, 38812, 38814, 38815, 38821, 38823, 38825, 38827, 38830, 38832, 38835, 38843, 38845, 38846, 38849, 38850, 38854, 38855, 38861, 38862, 38866, 38868, 38869, 38876, 38877, 38891, 38897, 38899, 38900, 38905, 38912, 38914, 38915, 38916, 38917, 38919, 38920, 38921, 38924, 38927, 38928, 38929, 38934, 38941, 38942, 38945, 38946, 38948, 38952, 38954, 38955, 38961, 38965, 38 ...

# %%
assert not test_recursion(lambda: map(factorial_iterative, range(5)))

# %% [markdown]
# Build the json object with recursion.
# Inspiration:
#
# https://stackoverflow.com/questions/65462806/how-to-parse-data-from-scikitlearn-agglomerative-clustering

# %%
def create_tree(linked, leaf_labels):
    ## inner func to recurvise-ly walk the linkage matrix
    def recurTree(tree):
        k = tree['clust']
        ## no children for this node
        if k not in inter:
            tree['nbd_no'] = int(leaf_labels[k])
            del tree["clust"]
            del tree["children"]
            return
        for n in inter[k]:
            ## build child nodes
            node = {
                "clust": int(n),
                "parent": k,
                "children": []
            }
            ## add to children
            tree['children'].append(node)
            ## next recursion
            recurTree(node)      
    
    num_rows, _ = linked.shape
    inter = {}
    i = 0
    # loop linked matrix convert to dictionary
    for row in linked:
        i += 1
        inter[i + num_rows] = [row[0],row[1]]

    # start tree data structure
    tree = {
        "clust": i + num_rows,
        #"parent": None,
        "children": []
    }
    # start recursion
    recurTree(tree);
    return tree

# %%
d = create_tree(linkage_matrix, nutrients_matrix.index)

# %%
json.dump(d, open(nutrient_matrix_data_p + 'hcluster_nutrients_' + metric + '_' + linkage + 'json', "w"))
